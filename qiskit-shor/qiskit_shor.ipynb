# %%
# %load_ext autoreload
# %autoreload 2
from qiskit_shor import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from qiskit_aer import AerSimulator

# %%
backend = AerSimulator(method='statevector')
shor_circuit = Shor(backend)
backend.name
# Out:
# 'aer_simulator'

# %%
shor_circuit.factor(15, 7)
# Out:
# ---------------------------------------------------------------------------
# DAGCircuitError                           Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 shor_circuit.factor(15, 7)
#
# File c:\Users\mvbon\Documents\Quantum-Computing\qiskit-shor\qiskit_shor.py:429, in Shor.factor(self, N, a)
#     423 circuit = self.construct_circuit(N=N, a=a, measurement=True)
#     425 # First decompose the circuit
#     426 # circuit = circuit.decompose()
#     427
#     428 # Then transpile with basic parameters
# --> 429 circuit = transpile(
#     430     circuit,
#     431     self.backend,
#     432     optimization_level=1,
#     433     layout_method="dense",
#     434     seed_transpiler=42,
#     435 )
#     437 job = self.backend.run(circuit)
#     438 counts = job.result().get_counts(circuit)
#
# ...
